# %% [markdown]
# <a href="https://colab.research.google.com/github/Tasyasyaaaaa/PembelajaranMesin/blob/main/VISUALISASI_DATA_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#    **TUGAS PEMBELAJARAN MESIN A**
#
#     Nama : Tasya
#     NIM  : H081221043
#     Prodi: Ilmu Aktuaria

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

kota = ['Jakarta', 'Makassar', 'Tangerang', 'Manado', 'Surabaya', 'Palembang', 'Medan', 'Bandung', 'Semarang', 'Yogyakarta']

tahun = ['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020','2021', '2022', '2023']

Jumlah_Penduduk = [
    [9.969, 10.075, 10.177, 10.277, 10.374, 10.428,	10.504, 10.562,	10.609,	10.680], # Jakarta
    [8.342, 8.432, 8.520, 8.606, 8.690, 8.748, 8.819, 9.073, 9.139, 9.225], # Makassar
    [11.452, 11.704, 11.955, 12.203, 12.448, 12.530,	12.714, 11.904,	12.061,	12.252], # Tangerang
    [2.360, 2.386, 2.412, 2.436, 2.461, 2.474, 2.494, 2.621, 2.638, 2.659], # Manado
    [36.363, 36.610, 38.847, 39.075, 39.293, 39.521, 39.744, 40.665, 40.878,	41.150], # Surabaya
    [7.828, 7.941, 8.052, 8.160, 8.267, 8.391, 8.497, 8.467,	8.550, 8.657], # Palembang
    [13.590, 13.766, 13.937, 14.102, 14.262, 14.476, 14.639, 14.799,	14.936,	15.115], # Medan
    [45.340, 46.029, 46.709, 47.397, 48.307, 48.475, 49.023, 48.274,	48.782,	49.405], # Bandung
    [33.264, 33.522, 33.774, 34.019, 34.257, 34.358, 34.552, 36.516,	36.742,	37.032], # Semarang
    [3.594, 3.637, 3.679, 3.720, 3.762, 3.818, 3.868, 3.668,	3.712,	3.761], # Yogyakarta
]

sns.heatmap(
    Jumlah_Penduduk,
    yticklabels=kota,
    xticklabels=tahun,
    cmap='coolwarm',
)
plt.show()

# %% [markdown]
# Dari heatmap diatas dapat dengan mudah melihat perbedaan kepadatan penduduk di berbagai kota. Kota-kota yang memiliki warna sel yang lebih gelap atau merah secara konsisten menunjukkan kepadatan penduduk yang lebih tinggi daripada kota-kota dengan warna sel yang lebih cerah atau biru. Ini mengindikasikan distribusi yang tidak merata dari jumlah penduduk di seluruh wilayah Indonesia.
#
# Dalam visualisasi heatmap jumlah penduduk beberapa kota di Indonesia dari tahun 2013 hingga 2022, beberapa pola dapat dilihat dengan jelas. Bandung secara konsisten menunjukkan kepadatan penduduk tertinggi, dengan warna sel yang cenderung lebih merah daripada kota lainnya, menunjukkan pertumbuhan penduduk yang stabil dari tahun ke tahun. Surabaya dan semarang juga menonjol dengan kepadatan penduduk yang tinggi, terutama pada tahun-tahun terakhir. Sementara itu, kota-kota seperti Manado, Yogyakarta, dan Palembang  cenderung memiliki kepadatan penduduk yang lebih rendah, ditunjukkan oleh warna sel yang lebih terang atau biru. Terdapat juga tren peningkatan jumlah penduduk dalam peningkatan yang sangat kecil di beberapa kota selama periode yang diamati, seperti Makassar, Jakarta, Yogyakarta, Medan, dan Palembang .Analisis heatmap ini memberikan wawasan yang berharga tentang pola distribusi dan perubahan jumlah penduduk di berbagai kota di Indonesia selama beberapa tahun terakhir.
