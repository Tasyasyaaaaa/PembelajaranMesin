# %% [markdown]
# <a href="https://colab.research.google.com/github/Tasyasyaaaaa/PembelajaranMesin/blob/main/World_University_Rankings_dataset_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TUGAS MACHINE LEARNING A**
#
#     Nama : Tasya
#     NIM  : H081221043
#     Prodi: Ilmu Aktuaria

# %%
import pandas as pd

# %%
dataset = '/content/timesData.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 0     United States of America      99.7          72.4      98.7       98.8
# 1     United States of America      97.7          54.6      98.0       99.9
# ...

# %%
data.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# ...

# %%
print(data.dtypes)
# Out:
# world_rank                 object
# university_name            object
# country                    object
# teaching                  float64
# international              object
# research                  float64
# citations                 float64
# income                     object
# total_score                object
# num_students               object
# student_staff_ratio       float64
# international_students     object
# female_male_ratio          object
# year                        int64
# dtype: object

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching  research  citations income  \
# 0     United States of America      99.7      98.7       98.8   34.5
# 1     United States of America      97.7      98.0       99.9   83.7
# 2     United States of America      97.8      91.4       99.9   87.5
# ...

# %%
data.describe()
# Out:
#           teaching     research    citations  student_staff_ratio         year
# count  2603.000000  2603.000000  2603.000000          2544.000000  2603.000000
# mean     37.801498    35.910257    60.921629            18.445283  2014.075682
# std      17.604218    21.254805    23.073219            11.458698     1.685733
# min       9.900000     2.900000     1.200000             0.600000  2011.000000
# 25%      24.700000    19.600000    45.500000            11.975000  2013.000000
# 50%      33.900000    30.500000    62.500000            16.100000  2014.000000
# 75%      46.400000    47.250000    79.050000            21.500000  2016.000000
# max      99.700000    99.400000   100.000000           162.600000  2016.000000

# %%
data.loc[:,"teaching":].corr()
# Out:
# <ipython-input-13-93f86c6131d2>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"teaching":].corr()
#                      teaching  research  citations  student_staff_ratio  \
# teaching             1.000000  0.913120   0.503867            -0.282630
# research             0.913120  1.000000   0.525264            -0.198841
# citations            0.503867  0.525264   1.000000            -0.137737
# student_staff_ratio -0.282630 -0.198841  -0.137737             1.000000
# year                -0.278108 -0.274451  -0.173544             0.060728
#
#                          year
# teaching            -0.278108
# research            -0.274451
# citations           -0.173544
# student_staff_ratio  0.060728
# year                 1.000000

# %% [markdown]
# **Dengan API**

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-109896fa-af48-45c6-94ee-237e4b6a7f26" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-109896fa-af48-45c6-94ee-237e4b6a7f26">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "rank university"
# Out:
# ...
# ref                                                      title                                      size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------  ----------------------------------------  -----  -------------------  -------------  ---------  ---------------
# mylesoneill/world-university-rankings                    World University Rankings                   1MB  2019-11-13 18:48:56          85401       1064  0.7941176
# alitaqi000/world-university-rankings-2023                World University Rankings 2023             70KB  2023-08-31 14:35:38           5533         79  1.0
# r1chardson/the-world-university-rankings-2011-2023       THE World University Rankings 2011-2024     2MB  2024-02-27 08:09:56           6162         97  1.0
# jkanthony/world-university-rankings-202223               World University Rankings 2023             57KB  2022-06-11 05:26:30           4923         61  0.9411765
# ...

# %%
# !kaggle datasets download mylesoneill/world-university-rankings
# Out:
# ...
#  71% 1.00M/1.41M [00:00<00:00, 1.99MB/s]
# 100% 1.41M/1.41M [00:00<00:00, 2.61MB/s]

# %%
# !unzip /content/world-university-rankings.zip
# Out:
# Archive:  /content/world-university-rankings.zip
#   inflating: cwurData.csv
#   inflating: education_expenditure_supplementary_data.csv
#   inflating: educational_attainment_supplementary_data.csv
#   inflating: school_and_country_table.csv
#   inflating: shanghaiData.csv
# replace timesData.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...
